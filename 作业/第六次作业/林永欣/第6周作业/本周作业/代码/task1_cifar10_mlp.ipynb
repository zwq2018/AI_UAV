# %% [markdown]
# ### 1. 加载cifar10数据集

# %%
import keras
from keras.datasets import cifar10  
import numpy as np
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train=y_train.flatten()
y_test=y_test.flatten()
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Using TensorFlow backend.
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000,)
# (10000,)

# %% [markdown]
# ### 2.缩放图片的像素，使每个图像中的每个像素处于0-1之间

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 3.  将数据集分解为训练、测试和验证集

# %%
from keras.utils import np_utils

# 对标签进行one-hot编码
num_classes = len(np.unique(y_train))  # num_class是输出的类别总数，np.unique去除数组中的重复数字，并进行排序
y_train = keras.utils.to_categorical(y_train, num_classes)  # 将y_train标签数据转为one-hot
y_test = keras.utils.to_categorical(y_test, num_classes) # 将y_test标签数据转为one-hot
print(num_classes)
print(y_train.shape)
print(y_test.shape)

# 将训练集分解为训练集和验证集
(x_train, x_valid) = x_train[5000:], x_train[:5000] # x_train取5000-49999的数据，x_valid取0-4999的数据
(y_train, y_valid) = y_train[5000:], y_train[:5000]

print('x_train shape:', x_train.shape)
print('x_valid shape:', x_valid.shape)
print('y_train shape:', y_train.shape)
print('y_valid shape:', y_valid.shape)
# Out:
# 10
# (50000, 10)
# (10000, 10)
# x_train shape: (45000, 32, 32, 3)
# x_valid shape: (5000, 32, 32, 3)
# y_train shape: (45000, 10)
# y_valid shape: (5000, 10)

# %% [markdown]
# ### 4. 使用keras构建神经网络

# %%
from keras.models import Sequential  # 序列模型
from keras.layers import Dense, Dropout, Flatten  

model = Sequential()  # 初始化序列模型
model.add(Flatten(input_shape = x_train.shape[1:])) # 把图像进行从矩阵形式分解成向量形式,输入层节点32*32*3=3072
model.add(Dense(1000, activation='relu'))  # 添加1000个节点的隐藏层，激活函数采用relu函数
model.add(Dropout(0.2))  # 使用dropout技术，概率为0.2
model.add(Dense(512, activation='relu'))  # 添加512个节点的隐藏层，激活函数采用relu函数
model.add(Dropout(0.2))  # 使用dropout技术，概率为0.2
model.add(Dense(num_classes, activation='softmax'))  # 输出层采用sotfmax激活函数

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              3073000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 3,590,642
# Trainable params: 3,590,642
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 5.编译构建好的模型

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])  # 使用分类交叉熵损失函数、优化器采用rmsprop

# %% [markdown]
# ### 6. 训练神经网络

# %%
from keras.callbacks import ModelCheckpoint  # 保存每次更新的权重

checkpointer = ModelCheckpoint(filepath=r'C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5', verbose=1, 
                               save_best_only=True)  
hist = model.fit(x_train, y_train, batch_size=10000, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 1s - loss: 1.6848 - acc: 0.3986 - val_loss: 1.6984 - val_acc: 0.4146
#
# Epoch 00001: val_loss improved from inf to 1.69842, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 2/100
#  - 1s - loss: 1.6684 - acc: 0.4112 - val_loss: 1.6440 - val_acc: 0.4138
#
# Epoch 00002: val_loss improved from 1.69842 to 1.64399, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 3/100
#  - 1s - loss: 1.6385 - acc: 0.4121 - val_loss: 1.7114 - val_acc: 0.3788
#
# Epoch 00003: val_loss did not improve from 1.64399
# Epoch 4/100
#  - 1s - loss: 1.7266 - acc: 0.3903 - val_loss: 1.6598 - val_acc: 0.4084
#
# Epoch 00004: val_loss did not improve from 1.64399
# Epoch 5/100
#  - 1s - loss: 1.6306 - acc: 0.4148 - val_loss: 1.6213 - val_acc: 0.4300
#
# Epoch 00005: val_loss improved from 1.64399 to 1.62127, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 6/100
#  - 1s - loss: 1.7230 - acc: 0.3863 - val_loss: 1.8419 - val_acc: 0.3278
#
# Epoch 00006: val_loss did not improve from 1.62127
# Epoch 7/100
#  - 1s - loss: 1.7171 - acc: 0.3862 - val_loss: 1.6427 - val_acc: 0.4152
#
# Epoch 00007: val_loss did not improve from 1.62127
# Epoch 8/100
#  - 1s - loss: 1.6424 - acc: 0.4099 - val_loss: 1.6598 - val_acc: 0.4126
#
# Epoch 00008: val_loss did not improve from 1.62127
# Epoch 9/100
#  - 1s - loss: 1.7070 - acc: 0.3938 - val_loss: 1.6018 - val_acc: 0.4410
#
# Epoch 00009: val_loss improved from 1.62127 to 1.60177, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 10/100
#  - 1s - loss: 1.7477 - acc: 0.3793 - val_loss: 1.7356 - val_acc: 0.3808
#
# Epoch 00010: val_loss did not improve from 1.60177
# Epoch 11/100
#  - 1s - loss: 1.6782 - acc: 0.3966 - val_loss: 1.5896 - val_acc: 0.4286
#
# Epoch 00011: val_loss improved from 1.60177 to 1.58959, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 12/100
#  - 1s - loss: 1.6238 - acc: 0.4206 - val_loss: 1.6967 - val_acc: 0.3996
#
# Epoch 00012: val_loss did not improve from 1.58959
# Epoch 13/100
#  - 1s - loss: 1.7174 - acc: 0.3912 - val_loss: 1.6392 - val_acc: 0.4206
#
# Epoch 00013: val_loss did not improve from 1.58959
# Epoch 14/100
#  - 1s - loss: 1.6299 - acc: 0.4173 - val_loss: 1.5755 - val_acc: 0.4510
#
# Epoch 00014: val_loss improved from 1.58959 to 1.57553, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 15/100
#  - 1s - loss: 1.6200 - acc: 0.4265 - val_loss: 1.7606 - val_acc: 0.3640
#
# Epoch 00015: val_loss did not improve from 1.57553
# Epoch 16/100
#  - 1s - loss: 1.7485 - acc: 0.3766 - val_loss: 1.6319 - val_acc: 0.4270
#
# Epoch 00016: val_loss did not improve from 1.57553
# Epoch 17/100
#  - 1s - loss: 1.6593 - acc: 0.4127 - val_loss: 1.7937 - val_acc: 0.3680
#
# Epoch 00017: val_loss did not improve from 1.57553
# Epoch 18/100
#  - 1s - loss: 1.7149 - acc: 0.3902 - val_loss: 1.6616 - val_acc: 0.4032
#
# Epoch 00018: val_loss did not improve from 1.57553
# Epoch 19/100
#  - 1s - loss: 1.5994 - acc: 0.4331 - val_loss: 1.6146 - val_acc: 0.4216
#
# Epoch 00019: val_loss did not improve from 1.57553
# Epoch 20/100
#  - 1s - loss: 1.6106 - acc: 0.4286 - val_loss: 1.7430 - val_acc: 0.3800
#
# Epoch 00020: val_loss did not improve from 1.57553
# Epoch 21/100
#  - 1s - loss: 1.6793 - acc: 0.3990 - val_loss: 1.6223 - val_acc: 0.4304
#
# Epoch 00021: val_loss did not improve from 1.57553
# Epoch 22/100
#  - 1s - loss: 1.6362 - acc: 0.4153 - val_loss: 1.6555 - val_acc: 0.4112
#
# Epoch 00022: val_loss did not improve from 1.57553
# Epoch 23/100
#  - 1s - loss: 1.6171 - acc: 0.4236 - val_loss: 1.6189 - val_acc: 0.4162
#
# Epoch 00023: val_loss did not improve from 1.57553
# Epoch 24/100
#  - 1s - loss: 1.6278 - acc: 0.4162 - val_loss: 1.8775 - val_acc: 0.3316
#
# Epoch 00024: val_loss did not improve from 1.57553
# Epoch 25/100
#  - 1s - loss: 1.8738 - acc: 0.3364 - val_loss: 1.6766 - val_acc: 0.4026
#
# Epoch 00025: val_loss did not improve from 1.57553
# Epoch 26/100
#  - 1s - loss: 1.6256 - acc: 0.4221 - val_loss: 1.5564 - val_acc: 0.4522
#
# Epoch 00026: val_loss improved from 1.57553 to 1.55643, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 27/100
#  - 1s - loss: 1.5864 - acc: 0.4402 - val_loss: 1.5533 - val_acc: 0.4536
#
# Epoch 00027: val_loss improved from 1.55643 to 1.55329, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 28/100
#  - 1s - loss: 1.5511 - acc: 0.4481 - val_loss: 1.7213 - val_acc: 0.3796
#
# Epoch 00028: val_loss did not improve from 1.55329
# Epoch 29/100
#  - 1s - loss: 1.7277 - acc: 0.3806 - val_loss: 1.7063 - val_acc: 0.3998
#
# Epoch 00029: val_loss did not improve from 1.55329
# Epoch 30/100
#  - 1s - loss: 1.6730 - acc: 0.4029 - val_loss: 1.6590 - val_acc: 0.4020
#
# Epoch 00030: val_loss did not improve from 1.55329
# Epoch 31/100
#  - 1s - loss: 1.6136 - acc: 0.4200 - val_loss: 1.5677 - val_acc: 0.4512
#
# Epoch 00031: val_loss did not improve from 1.55329
# Epoch 32/100
#  - 1s - loss: 1.5974 - acc: 0.4352 - val_loss: 1.6047 - val_acc: 0.4278
#
# Epoch 00032: val_loss did not improve from 1.55329
# Epoch 33/100
#  - 1s - loss: 1.6122 - acc: 0.4235 - val_loss: 1.6089 - val_acc: 0.4380
#
# Epoch 00033: val_loss did not improve from 1.55329
# Epoch 34/100
#  - 1s - loss: 1.6141 - acc: 0.4279 - val_loss: 1.5670 - val_acc: 0.4382
#
# Epoch 00034: val_loss did not improve from 1.55329
# Epoch 35/100
#  - 1s - loss: 1.5793 - acc: 0.4326 - val_loss: 1.6042 - val_acc: 0.4210
#
# Epoch 00035: val_loss did not improve from 1.55329
# Epoch 36/100
#  - 1s - loss: 1.5739 - acc: 0.4346 - val_loss: 1.5813 - val_acc: 0.4376
#
# Epoch 00036: val_loss did not improve from 1.55329
# Epoch 37/100
#  - 1s - loss: 1.6450 - acc: 0.4162 - val_loss: 1.6849 - val_acc: 0.4100
#
# Epoch 00037: val_loss did not improve from 1.55329
# Epoch 38/100
#  - 1s - loss: 1.5943 - acc: 0.4310 - val_loss: 1.6658 - val_acc: 0.4078
#
# Epoch 00038: val_loss did not improve from 1.55329
# Epoch 39/100
#  - 1s - loss: 1.6143 - acc: 0.4230 - val_loss: 1.5865 - val_acc: 0.4330
#
# Epoch 00039: val_loss did not improve from 1.55329
# Epoch 40/100
#  - 1s - loss: 1.5666 - acc: 0.4406 - val_loss: 1.6404 - val_acc: 0.4014
#
# Epoch 00040: val_loss did not improve from 1.55329
# Epoch 41/100
#  - 1s - loss: 1.6854 - acc: 0.3953 - val_loss: 1.6162 - val_acc: 0.4338
#
# Epoch 00041: val_loss did not improve from 1.55329
# Epoch 42/100
#  - 1s - loss: 1.6050 - acc: 0.4344 - val_loss: 1.5906 - val_acc: 0.4384
#
# Epoch 00042: val_loss did not improve from 1.55329
# Epoch 43/100
#  - 1s - loss: 1.5271 - acc: 0.4522 - val_loss: 1.5814 - val_acc: 0.4406
#
# Epoch 00043: val_loss did not improve from 1.55329
# Epoch 44/100
#  - 1s - loss: 1.5919 - acc: 0.4322 - val_loss: 1.6816 - val_acc: 0.3986
#
# Epoch 00044: val_loss did not improve from 1.55329
# Epoch 45/100
#  - 1s - loss: 1.6085 - acc: 0.4277 - val_loss: 1.5927 - val_acc: 0.4222
#
# Epoch 00045: val_loss did not improve from 1.55329
# Epoch 46/100
#  - 1s - loss: 1.5589 - acc: 0.4423 - val_loss: 1.6152 - val_acc: 0.4308
#
# Epoch 00046: val_loss did not improve from 1.55329
# Epoch 47/100
#  - 1s - loss: 1.5850 - acc: 0.4350 - val_loss: 1.5864 - val_acc: 0.4370
#
# Epoch 00047: val_loss did not improve from 1.55329
# Epoch 48/100
#  - 1s - loss: 1.6436 - acc: 0.4177 - val_loss: 1.5609 - val_acc: 0.4554
#
# Epoch 00048: val_loss did not improve from 1.55329
# Epoch 49/100
#  - 1s - loss: 1.5170 - acc: 0.4611 - val_loss: 1.5998 - val_acc: 0.4398
#
# Epoch 00049: val_loss did not improve from 1.55329
# Epoch 50/100
#  - 1s - loss: 1.5987 - acc: 0.4374 - val_loss: 1.8344 - val_acc: 0.3568
#
# Epoch 00050: val_loss did not improve from 1.55329
# Epoch 51/100
#  - 1s - loss: 1.7202 - acc: 0.3836 - val_loss: 1.5384 - val_acc: 0.4606
#
# Epoch 00051: val_loss improved from 1.55329 to 1.53844, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 52/100
#  - 1s - loss: 1.5731 - acc: 0.4396 - val_loss: 1.6240 - val_acc: 0.4176
#
# Epoch 00052: val_loss did not improve from 1.53844
# Epoch 53/100
#  - 1s - loss: 1.5433 - acc: 0.4461 - val_loss: 1.5469 - val_acc: 0.4582
#
# Epoch 00053: val_loss did not improve from 1.53844
# Epoch 54/100
#  - 1s - loss: 1.5088 - acc: 0.4638 - val_loss: 1.6418 - val_acc: 0.4224
#
# Epoch 00054: val_loss did not improve from 1.53844
# Epoch 55/100
#  - 1s - loss: 1.5388 - acc: 0.4546 - val_loss: 1.6237 - val_acc: 0.4282
#
# Epoch 00055: val_loss did not improve from 1.53844
# Epoch 56/100
#  - 1s - loss: 1.6310 - acc: 0.4172 - val_loss: 1.5351 - val_acc: 0.4590
#
# Epoch 00056: val_loss improved from 1.53844 to 1.53508, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 57/100
#  - 1s - loss: 1.5056 - acc: 0.4577 - val_loss: 1.5285 - val_acc: 0.4554
#
# Epoch 00057: val_loss improved from 1.53508 to 1.52855, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 58/100
#  - 1s - loss: 1.5476 - acc: 0.4532 - val_loss: 1.5999 - val_acc: 0.4290
#
# Epoch 00058: val_loss did not improve from 1.52855
# Epoch 59/100
#  - 1s - loss: 1.6082 - acc: 0.4247 - val_loss: 1.6553 - val_acc: 0.4096
#
# Epoch 00059: val_loss did not improve from 1.52855
# Epoch 60/100
#  - 1s - loss: 1.5607 - acc: 0.4348 - val_loss: 1.5820 - val_acc: 0.4358
#
# Epoch 00060: val_loss did not improve from 1.52855
# Epoch 61/100
#  - 1s - loss: 1.4884 - acc: 0.4666 - val_loss: 1.5566 - val_acc: 0.4416
#
# Epoch 00061: val_loss did not improve from 1.52855
# Epoch 62/100
#  - 1s - loss: 1.5749 - acc: 0.4428 - val_loss: 1.7952 - val_acc: 0.3740
#
# Epoch 00062: val_loss did not improve from 1.52855
# Epoch 63/100
#  - 1s - loss: 1.6596 - acc: 0.4134 - val_loss: 1.5364 - val_acc: 0.4458
#
# Epoch 00063: val_loss did not improve from 1.52855
# Epoch 64/100
#  - 1s - loss: 1.5121 - acc: 0.4620 - val_loss: 1.5778 - val_acc: 0.4514
#
# Epoch 00064: val_loss did not improve from 1.52855
# Epoch 65/100
#  - 1s - loss: 1.5371 - acc: 0.4562 - val_loss: 1.5708 - val_acc: 0.4452
#
# Epoch 00065: val_loss did not improve from 1.52855
# Epoch 66/100
#  - 1s - loss: 1.5012 - acc: 0.4644 - val_loss: 1.4869 - val_acc: 0.4712
#
# Epoch 00066: val_loss improved from 1.52855 to 1.48695, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 67/100
#  - 1s - loss: 1.4680 - acc: 0.4755 - val_loss: 1.5966 - val_acc: 0.4292
#
# Epoch 00067: val_loss did not improve from 1.48695
# Epoch 68/100
#  - 1s - loss: 1.7401 - acc: 0.3819 - val_loss: 1.7630 - val_acc: 0.3676
#
# Epoch 00068: val_loss did not improve from 1.48695
# Epoch 69/100
#  - 1s - loss: 1.5631 - acc: 0.4444 - val_loss: 1.6441 - val_acc: 0.4246
#
# Epoch 00069: val_loss did not improve from 1.48695
# Epoch 70/100
#  - 1s - loss: 1.5251 - acc: 0.4539 - val_loss: 1.4950 - val_acc: 0.4698
#
# Epoch 00070: val_loss did not improve from 1.48695
# Epoch 71/100
#  - 1s - loss: 1.5429 - acc: 0.4513 - val_loss: 1.5588 - val_acc: 0.4404
#
# Epoch 00071: val_loss did not improve from 1.48695
# Epoch 72/100
#  - 1s - loss: 1.5077 - acc: 0.4614 - val_loss: 1.5690 - val_acc: 0.4362
#
# Epoch 00072: val_loss did not improve from 1.48695
# Epoch 73/100
#  - 1s - loss: 1.5812 - acc: 0.4335 - val_loss: 1.4944 - val_acc: 0.4762
#
# Epoch 00073: val_loss did not improve from 1.48695
# Epoch 74/100
#  - 1s - loss: 1.4832 - acc: 0.4763 - val_loss: 1.6388 - val_acc: 0.4122
#
# Epoch 00074: val_loss did not improve from 1.48695
# Epoch 75/100
#  - 1s - loss: 1.5200 - acc: 0.4570 - val_loss: 1.5275 - val_acc: 0.4526
#
# Epoch 00075: val_loss did not improve from 1.48695
# Epoch 76/100
#  - 1s - loss: 1.5055 - acc: 0.4613 - val_loss: 1.5549 - val_acc: 0.4564
#
# Epoch 00076: val_loss did not improve from 1.48695
# Epoch 77/100
#  - 1s - loss: 1.5744 - acc: 0.4448 - val_loss: 1.5767 - val_acc: 0.4314
#
# Epoch 00077: val_loss did not improve from 1.48695
# Epoch 78/100
#  - 1s - loss: 1.4928 - acc: 0.4679 - val_loss: 1.6387 - val_acc: 0.4172
#
# Epoch 00078: val_loss did not improve from 1.48695
# Epoch 79/100
#  - 1s - loss: 1.5203 - acc: 0.4594 - val_loss: 1.5305 - val_acc: 0.4628
#
# Epoch 00079: val_loss did not improve from 1.48695
# Epoch 80/100
#  - 1s - loss: 1.5003 - acc: 0.4621 - val_loss: 1.5401 - val_acc: 0.4468
#
# Epoch 00080: val_loss did not improve from 1.48695
# Epoch 81/100
#  - 1s - loss: 1.4782 - acc: 0.4713 - val_loss: 1.5616 - val_acc: 0.4548
#
# Epoch 00081: val_loss did not improve from 1.48695
# Epoch 82/100
#  - 1s - loss: 1.5974 - acc: 0.4371 - val_loss: 1.5666 - val_acc: 0.4336
#
# Epoch 00082: val_loss did not improve from 1.48695
# Epoch 83/100
#  - 1s - loss: 1.4577 - acc: 0.4738 - val_loss: 1.5518 - val_acc: 0.4528
#
# Epoch 00083: val_loss did not improve from 1.48695
# Epoch 84/100
#  - 1s - loss: 1.4833 - acc: 0.4719 - val_loss: 1.5451 - val_acc: 0.4628
#
# Epoch 00084: val_loss did not improve from 1.48695
# Epoch 85/100
#  - 1s - loss: 1.4654 - acc: 0.4758 - val_loss: 1.5848 - val_acc: 0.4366
#
# Epoch 00085: val_loss did not improve from 1.48695
# Epoch 86/100
#  - 1s - loss: 1.6051 - acc: 0.4309 - val_loss: 1.5576 - val_acc: 0.4478
#
# Epoch 00086: val_loss did not improve from 1.48695
# Epoch 87/100
#  - 1s - loss: 1.4769 - acc: 0.4730 - val_loss: 1.4730 - val_acc: 0.4698
#
# Epoch 00087: val_loss improved from 1.48695 to 1.47297, saving model to C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5
# Epoch 88/100
#  - 1s - loss: 1.4591 - acc: 0.4793 - val_loss: 1.5467 - val_acc: 0.4594
#
# Epoch 00088: val_loss did not improve from 1.47297
# Epoch 89/100
#  - 1s - loss: 1.5281 - acc: 0.4565 - val_loss: 1.5518 - val_acc: 0.4488
#
# Epoch 00089: val_loss did not improve from 1.47297
# Epoch 90/100
#  - 1s - loss: 1.4835 - acc: 0.4703 - val_loss: 1.4920 - val_acc: 0.4706
#
# Epoch 00090: val_loss did not improve from 1.47297
# Epoch 91/100
#  - 1s - loss: 1.5101 - acc: 0.4613 - val_loss: 1.5654 - val_acc: 0.4432
#
# Epoch 00091: val_loss did not improve from 1.47297
# Epoch 92/100
#  - 1s - loss: 1.4535 - acc: 0.4788 - val_loss: 1.4969 - val_acc: 0.4700
#
# Epoch 00092: val_loss did not improve from 1.47297
# Epoch 93/100
#  - 1s - loss: 1.4629 - acc: 0.4789 - val_loss: 1.4983 - val_acc: 0.4672
#
# Epoch 00093: val_loss did not improve from 1.47297
# Epoch 94/100
#  - 1s - loss: 1.4415 - acc: 0.4886 - val_loss: 1.8034 - val_acc: 0.3646
#
# Epoch 00094: val_loss did not improve from 1.47297
# Epoch 95/100
#  - 1s - loss: 1.7067 - acc: 0.4003 - val_loss: 1.5602 - val_acc: 0.4522
#
# Epoch 00095: val_loss did not improve from 1.47297
# Epoch 96/100
#  - 1s - loss: 1.4683 - acc: 0.4753 - val_loss: 1.4932 - val_acc: 0.4694
#
# Epoch 00096: val_loss did not improve from 1.47297
# Epoch 97/100
#  - 1s - loss: 1.4258 - acc: 0.4912 - val_loss: 1.5416 - val_acc: 0.4594
#
# Epoch 00097: val_loss did not improve from 1.47297
# Epoch 98/100
#  - 1s - loss: 1.5245 - acc: 0.4588 - val_loss: 1.5158 - val_acc: 0.4668
#
# Epoch 00098: val_loss did not improve from 1.47297
# Epoch 99/100
#  - 1s - loss: 1.4426 - acc: 0.4853 - val_loss: 1.4885 - val_acc: 0.4766
#
# Epoch 00099: val_loss did not improve from 1.47297
# Epoch 100/100
#  - 1s - loss: 1.4705 - acc: 0.4751 - val_loss: 1.4987 - val_acc: 0.4734
#
# Epoch 00100: val_loss did not improve from 1.47297

# %% [markdown]
# ### 7. 加载分类精度最好的模型

# %%
model.load_weights(r'C:\Users\linyongxin\Desktop\MLP.weights.best.hdf5')

# %% [markdown]
# ### 8. 用测试集来测试模型的精度

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.4762
