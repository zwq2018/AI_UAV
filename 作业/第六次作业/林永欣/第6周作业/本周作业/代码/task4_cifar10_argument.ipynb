# %% [markdown]
# ### 1. 加载caifar10数据集

# %%
import keras
from keras.datasets import cifar10  
import numpy as np
import matplotlib.pyplot as plt  
# %matplotlib inline

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train=y_train.flatten()
y_test=y_test.flatten()
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# Using TensorFlow backend.
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000,)
# (10000,)

# %% [markdown]
# ### 2.缩放图片的像素，使每个图像中的每个像素处于0-1之间

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 3.  将数据集分解为训练、测试和验证集

# %%
from keras.utils import np_utils

# 对标签进行one-hot编码
num_classes = len(np.unique(y_train))  # num_class是输出的类别总数，np.unique去除数组中的重复数字，并进行排序
y_train = keras.utils.to_categorical(y_train, num_classes)  # 将y_train标签数据转为one-hot
y_test = keras.utils.to_categorical(y_test, num_classes) # 将y_test标签数据转为one-hot
print(num_classes)
print(y_train.shape)
print(y_test.shape)

# 将训练集分解为训练集和验证集
(x_train, x_valid) = x_train[5000:], x_train[:5000] # x_train取5000-49999的数据，x_valid取0-4999的数据
(y_train, y_valid) = y_train[5000:], y_train[:5000]

print('x_train shape:', x_train.shape)
print('x_valid shape:', x_valid.shape)
print('y_train shape:', y_train.shape)
print('y_valid shape:', y_valid.shape)
# Out:
# 10
# (50000, 10)
# (10000, 10)
# x_train shape: (45000, 32, 32, 3)
# x_valid shape: (5000, 32, 32, 3)
# y_train shape: (45000, 10)
# y_valid shape: (5000, 10)

# %% [markdown]
# ### 4.图片增强处理

# %%
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# 创建增强图像生成器并设置相关参数
argument_train = ImageDataGenerator(
    rotation_range = 0.1,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True)

argument_train.fit(x_train)

# 从原始图片中选取部分图片
x_train_subset = x_train[:12]

# 可视化部分原始图片
fig = plt.figure(figsize=(20,2))
fig.suptitle('Original Images', fontsize=20)
for i in range(0, len(x_train_subset)):  
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
plt.show()

# 可视化增强处理后的图片
fig = plt.figure(figsize=(20,2))
for x_batch in argument_train.flow(x_train_subset, batch_size=12): # 以每12张图为一批次进行图像增强处理
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 5.使用keras构建卷积神经网络

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# 第一层卷积层的参数定义
FILTER1_NUM = 16   # 过滤器的个数是1
FILTER1_SIZE = 2   # 过滤器的尺寸为2*2
FILTER1_STRIDES = 1  # 设置步长为1
PADDING1 = 'same'  # 经过卷积层后的大小不变 
ACTIVATION1 = 'relu'  # 采用relu激活函数 
# 第一层池化层的参数定义
POOL1_SIZE = 2  # 池化大小为2

# 第二层卷积层的参数定义
FILTER2_NUM = 32
FILTER2_SIZE = 2
FILTER2_STRIDES = 1
PADDING2 = 'same'
ACTIVATION2 = 'relu'
model = Sequential()
# 第二层池化层的参数定义
POOL2_SIZE = 2

# 第三层卷积层的参数定义
FILTER3_NUM = 64
FILTER3_SIZE = 2
FILTER3_STRIDES = 1
PADDING3 = 'same'
ACTIVATION3 = 'relu'
# 第三层池化层的参数定义
POOL3_SIZE = 2

model = Sequential()
# 添加第一层卷积层和池化层，第一层卷积层采用16个卷积过滤器，尺寸为2*2，分别对3层的图片进行处理
model.add(Conv2D(filters=FILTER1_NUM,  
                kernel_size=FILTER1_SIZE,  
                strides=FILTER1_STRIDES,  
                padding=PADDING1,  
                activation=ACTIVATION1,   
                input_shape=(x_train.shape[1], x_train.shape[2], x_train.shape[3])# input_shape为高度、宽度、深度
                ))
model.add(MaxPooling2D(pool_size=POOL1_SIZE)) # 添加池化层，采用最大池化，大小为2

#添加第二层卷积层和池化层
model.add(Conv2D(filters=FILTER2_NUM, 
                 kernel_size=FILTER2_SIZE,
                 strides=FILTER2_STRIDES,
                 padding=PADDING2, 
                 activation=ACTIVATION2))
model.add(MaxPooling2D(pool_size=POOL2_SIZE))  # 添加池化层，采用最大池化，大小为2

#添加第三层卷积层和池化层
model.add(Conv2D(filters=FILTER3_NUM, 
                 kernel_size=FILTER3_SIZE,
                 strides=FILTER3_STRIDES,
                 padding=PADDING3, 
                 activation=ACTIVATION3))
model.add(MaxPooling2D(pool_size=POOL3_SIZE)) # 添加池化层，采用最大池化，大小为2

model.add(Dropout(0.2))  # dropout技术防止过拟合，丢弃的概率为0.3
model.add(Flatten())  # 扁平化矩阵，此时已经提取相关特征，对空间信息已不关心
model.add(Dense(1024, activation='relu'))  # 激活函数采用relu函数
model.add(Dropout(0.3))  # dropout技术防止过拟合，丢弃的概率为0.3
model.add(Dense(10, activation='softmax'))  # 输出节点为10，激活函数采用softmax函数

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 1,070,394
# Trainable params: 1,070,394
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. 编译模型

# %%
model.compile(loss='categorical_crossentropy',  # 采用分类交叉熵损失函数
              optimizer="Adam" ,  # 优化器使用Adam
              metrics=['accuracy'])

# %% [markdown]
# ### 7.训练构建好的卷积神经网络

# %%
from keras.callbacks import ModelCheckpoint  # 保存每次更新的权重

BATCH_SIZE = 80
EPOCHS = 50

checkpointer = ModelCheckpoint(filepath=r'C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5', 
                               verbose=1, 
                               save_best_only=True)  

# 使用fit_generator来拟合训练具有图像增强效果后的图片
model.fit_generator(argument_train.flow(x_train, y_train, batch_size=BATCH_SIZE),  
                    steps_per_epoch=x_train.shape[0] // BATCH_SIZE,  # steps_per_epoch代表每个迭代中计算的步数                    epochs=EPOCHS, verbose=2, callbacks=[checkpointer], 
                    epochs=EPOCHS, verbose=2, callbacks=[checkpointer],
                    validation_data=(x_valid, y_valid),
                    validation_steps=x_valid.shape[0] // BATCH_SIZE)
# Out:
# Epoch 1/100
#  - 12s - loss: 1.6412 - acc: 0.4027 - val_loss: 1.3869 - val_acc: 0.4880
#
# Epoch 00001: val_loss improved from inf to 1.38687, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 2/100
#  - 10s - loss: 1.3692 - acc: 0.5060 - val_loss: 1.1793 - val_acc: 0.5798
#
# Epoch 00002: val_loss improved from 1.38687 to 1.17933, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 3/100
#  - 10s - loss: 1.2564 - acc: 0.5495 - val_loss: 1.1293 - val_acc: 0.5970
#
# Epoch 00003: val_loss improved from 1.17933 to 1.12931, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 4/100
#  - 10s - loss: 1.1839 - acc: 0.5752 - val_loss: 1.1368 - val_acc: 0.6190
#
# Epoch 00004: val_loss did not improve from 1.12931
# Epoch 5/100
#  - 10s - loss: 1.1260 - acc: 0.5994 - val_loss: 0.9567 - val_acc: 0.6568
#
# Epoch 00005: val_loss improved from 1.12931 to 0.95667, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 6/100
#  - 10s - loss: 1.0777 - acc: 0.6178 - val_loss: 0.9664 - val_acc: 0.6520
#
# Epoch 00006: val_loss did not improve from 0.95667
# Epoch 7/100
#  - 10s - loss: 1.0358 - acc: 0.6338 - val_loss: 0.9328 - val_acc: 0.6728
#
# Epoch 00007: val_loss improved from 0.95667 to 0.93282, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 8/100
#  - 10s - loss: 1.0040 - acc: 0.6443 - val_loss: 0.8701 - val_acc: 0.6946
#
# Epoch 00008: val_loss improved from 0.93282 to 0.87006, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 9/100
#  - 10s - loss: 0.9768 - acc: 0.6535 - val_loss: 0.8657 - val_acc: 0.6982
#
# Epoch 00009: val_loss improved from 0.87006 to 0.86572, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 10/100
#  - 10s - loss: 0.9434 - acc: 0.6660 - val_loss: 0.8243 - val_acc: 0.7128
#
# Epoch 00010: val_loss improved from 0.86572 to 0.82435, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 11/100
#  - 10s - loss: 0.9211 - acc: 0.6720 - val_loss: 0.8038 - val_acc: 0.7132
#
# Epoch 00011: val_loss improved from 0.82435 to 0.80378, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 12/100
#  - 10s - loss: 0.8941 - acc: 0.6831 - val_loss: 0.7980 - val_acc: 0.7186
#
# Epoch 00012: val_loss improved from 0.80378 to 0.79803, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 13/100
#  - 10s - loss: 0.8803 - acc: 0.6894 - val_loss: 0.7757 - val_acc: 0.7292
#
# Epoch 00013: val_loss improved from 0.79803 to 0.77571, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 14/100
#  - 10s - loss: 0.8551 - acc: 0.6963 - val_loss: 0.7479 - val_acc: 0.7342
#
# Epoch 00014: val_loss improved from 0.77571 to 0.74787, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 15/100
#  - 10s - loss: 0.8442 - acc: 0.7017 - val_loss: 0.7444 - val_acc: 0.7482
#
# Epoch 00015: val_loss improved from 0.74787 to 0.74444, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 16/100
#  - 10s - loss: 0.8265 - acc: 0.7062 - val_loss: 0.7570 - val_acc: 0.7382
#
# Epoch 00016: val_loss did not improve from 0.74444
# Epoch 17/100
#  - 10s - loss: 0.8091 - acc: 0.7153 - val_loss: 0.6989 - val_acc: 0.7584
#
# Epoch 00017: val_loss improved from 0.74444 to 0.69886, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 18/100
#  - 10s - loss: 0.7988 - acc: 0.7171 - val_loss: 0.6824 - val_acc: 0.7600
#
# Epoch 00018: val_loss improved from 0.69886 to 0.68237, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 19/100
#  - 10s - loss: 0.7890 - acc: 0.7216 - val_loss: 0.7119 - val_acc: 0.7508
#
# Epoch 00019: val_loss did not improve from 0.68237
# Epoch 20/100
#  - 10s - loss: 0.7739 - acc: 0.7261 - val_loss: 0.7139 - val_acc: 0.7542
#
# Epoch 00020: val_loss did not improve from 0.68237
# Epoch 21/100
#  - 10s - loss: 0.7625 - acc: 0.7279 - val_loss: 0.7349 - val_acc: 0.7454
#
# Epoch 00021: val_loss did not improve from 0.68237
# Epoch 22/100
#  - 10s - loss: 0.7563 - acc: 0.7322 - val_loss: 0.7068 - val_acc: 0.7514
#
# Epoch 00022: val_loss did not improve from 0.68237
# Epoch 23/100
#  - 10s - loss: 0.7470 - acc: 0.7361 - val_loss: 0.6648 - val_acc: 0.7674
#
# Epoch 00023: val_loss improved from 0.68237 to 0.66482, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 24/100
#  - 10s - loss: 0.7391 - acc: 0.7385 - val_loss: 0.6942 - val_acc: 0.7598
#
# Epoch 00024: val_loss did not improve from 0.66482
# Epoch 25/100
#  - 10s - loss: 0.7293 - acc: 0.7401 - val_loss: 0.6621 - val_acc: 0.7704
#
# Epoch 00025: val_loss improved from 0.66482 to 0.66209, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 26/100
#  - 10s - loss: 0.7153 - acc: 0.7467 - val_loss: 0.6843 - val_acc: 0.7690
#
# Epoch 00026: val_loss did not improve from 0.66209
# Epoch 27/100
#  - 10s - loss: 0.7094 - acc: 0.7506 - val_loss: 0.6632 - val_acc: 0.7762
#
# Epoch 00027: val_loss did not improve from 0.66209
# Epoch 28/100
#  - 10s - loss: 0.6980 - acc: 0.7534 - val_loss: 0.6534 - val_acc: 0.7726
#
# Epoch 00028: val_loss improved from 0.66209 to 0.65339, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 29/100
#  - 10s - loss: 0.6919 - acc: 0.7567 - val_loss: 0.6564 - val_acc: 0.7700
#
# Epoch 00029: val_loss did not improve from 0.65339
# Epoch 30/100
#  - 10s - loss: 0.6830 - acc: 0.7569 - val_loss: 0.6664 - val_acc: 0.7696
#
# Epoch 00030: val_loss did not improve from 0.65339
# Epoch 31/100
#  - 10s - loss: 0.6734 - acc: 0.7640 - val_loss: 0.6211 - val_acc: 0.7814
#
# Epoch 00031: val_loss improved from 0.65339 to 0.62109, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 32/100
#  - 10s - loss: 0.6714 - acc: 0.7629 - val_loss: 0.6224 - val_acc: 0.7832
#
# Epoch 00032: val_loss did not improve from 0.62109
# Epoch 33/100
#  - 10s - loss: 0.6704 - acc: 0.7629 - val_loss: 0.6437 - val_acc: 0.7746
#
# Epoch 00033: val_loss did not improve from 0.62109
# Epoch 34/100
#  - 10s - loss: 0.6603 - acc: 0.7664 - val_loss: 0.6570 - val_acc: 0.7772
#
# Epoch 00034: val_loss did not improve from 0.62109
# Epoch 35/100
#  - 10s - loss: 0.6577 - acc: 0.7666 - val_loss: 0.6389 - val_acc: 0.7780
#
# Epoch 00035: val_loss did not improve from 0.62109
# Epoch 36/100
#  - 10s - loss: 0.6496 - acc: 0.7733 - val_loss: 0.6413 - val_acc: 0.7790
#
# Epoch 00036: val_loss did not improve from 0.62109
# Epoch 37/100
#  - 10s - loss: 0.6491 - acc: 0.7710 - val_loss: 0.6064 - val_acc: 0.7922
#
# Epoch 00037: val_loss improved from 0.62109 to 0.60644, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 38/100
#  - 10s - loss: 0.6350 - acc: 0.7745 - val_loss: 0.6410 - val_acc: 0.7788
#
# Epoch 00038: val_loss did not improve from 0.60644
# Epoch 39/100
#  - 10s - loss: 0.6381 - acc: 0.7735 - val_loss: 0.6282 - val_acc: 0.7888
#
# Epoch 00039: val_loss did not improve from 0.60644
# Epoch 40/100
#  - 10s - loss: 0.6324 - acc: 0.7758 - val_loss: 0.6092 - val_acc: 0.7938
#
# Epoch 00040: val_loss did not improve from 0.60644
# Epoch 41/100
#  - 10s - loss: 0.6277 - acc: 0.7790 - val_loss: 0.6500 - val_acc: 0.7804
#
# Epoch 00041: val_loss did not improve from 0.60644
# Epoch 42/100
#  - 10s - loss: 0.6235 - acc: 0.7768 - val_loss: 0.6244 - val_acc: 0.7864
#
# Epoch 00042: val_loss did not improve from 0.60644
# Epoch 43/100
#  - 10s - loss: 0.6217 - acc: 0.7807 - val_loss: 0.6094 - val_acc: 0.7868
#
# Epoch 00043: val_loss did not improve from 0.60644
# Epoch 44/100
#  - 10s - loss: 0.6138 - acc: 0.7852 - val_loss: 0.6361 - val_acc: 0.7794
#
# Epoch 00044: val_loss did not improve from 0.60644
# Epoch 45/100
#  - 10s - loss: 0.6123 - acc: 0.7850 - val_loss: 0.6093 - val_acc: 0.7936
#
# Epoch 00045: val_loss did not improve from 0.60644
# Epoch 46/100
#  - 10s - loss: 0.6047 - acc: 0.7865 - val_loss: 0.6060 - val_acc: 0.7940
#
# Epoch 00046: val_loss improved from 0.60644 to 0.60601, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 47/100
#  - 10s - loss: 0.6088 - acc: 0.7826 - val_loss: 0.6092 - val_acc: 0.7946
#
# Epoch 00047: val_loss did not improve from 0.60601
# Epoch 48/100
#  - 10s - loss: 0.5951 - acc: 0.7882 - val_loss: 0.6100 - val_acc: 0.7912
#
# Epoch 00048: val_loss did not improve from 0.60601
# Epoch 49/100
#  - 10s - loss: 0.6012 - acc: 0.7880 - val_loss: 0.6644 - val_acc: 0.7792
#
# Epoch 00049: val_loss did not improve from 0.60601
# Epoch 50/100
#  - 10s - loss: 0.5899 - acc: 0.7892 - val_loss: 0.5955 - val_acc: 0.7972
#
# Epoch 00050: val_loss improved from 0.60601 to 0.59549, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 51/100
#  - 10s - loss: 0.5942 - acc: 0.7892 - val_loss: 0.6064 - val_acc: 0.7960
#
# Epoch 00051: val_loss did not improve from 0.59549
# Epoch 52/100
#  - 10s - loss: 0.5839 - acc: 0.7945 - val_loss: 0.5842 - val_acc: 0.8020
#
# Epoch 00052: val_loss improved from 0.59549 to 0.58418, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 53/100
#  - 10s - loss: 0.5819 - acc: 0.7930 - val_loss: 0.5919 - val_acc: 0.8032
#
# Epoch 00053: val_loss did not improve from 0.58418
# Epoch 54/100
#  - 10s - loss: 0.5738 - acc: 0.7980 - val_loss: 0.6203 - val_acc: 0.7942
#
# Epoch 00054: val_loss did not improve from 0.58418
# Epoch 55/100
#  - 10s - loss: 0.5786 - acc: 0.7941 - val_loss: 0.5877 - val_acc: 0.8054
#
# Epoch 00055: val_loss did not improve from 0.58418
# Epoch 56/100
#  - 10s - loss: 0.5788 - acc: 0.7970 - val_loss: 0.6086 - val_acc: 0.7942
#
# Epoch 00056: val_loss did not improve from 0.58418
# Epoch 57/100
#  - 10s - loss: 0.5678 - acc: 0.8007 - val_loss: 0.6161 - val_acc: 0.7992
#
# Epoch 00057: val_loss did not improve from 0.58418
# Epoch 58/100
#  - 10s - loss: 0.5662 - acc: 0.8000 - val_loss: 0.6123 - val_acc: 0.7910
#
# Epoch 00058: val_loss did not improve from 0.58418
# Epoch 59/100
#  - 10s - loss: 0.5576 - acc: 0.8019 - val_loss: 0.6097 - val_acc: 0.7950
#
# Epoch 00059: val_loss did not improve from 0.58418
# Epoch 60/100
#  - 10s - loss: 0.5649 - acc: 0.7994 - val_loss: 0.6071 - val_acc: 0.7964
#
# Epoch 00060: val_loss did not improve from 0.58418
# Epoch 61/100
#  - 10s - loss: 0.5540 - acc: 0.8037 - val_loss: 0.5832 - val_acc: 0.8078
#
# Epoch 00061: val_loss improved from 0.58418 to 0.58323, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 62/100
#  - 10s - loss: 0.5520 - acc: 0.8038 - val_loss: 0.6001 - val_acc: 0.7940
#
# Epoch 00062: val_loss did not improve from 0.58323
# Epoch 63/100
#  - 10s - loss: 0.5554 - acc: 0.8028 - val_loss: 0.6018 - val_acc: 0.7942
#
# Epoch 00063: val_loss did not improve from 0.58323
# Epoch 64/100
#  - 10s - loss: 0.5575 - acc: 0.8008 - val_loss: 0.6119 - val_acc: 0.7910
#
# Epoch 00064: val_loss did not improve from 0.58323
# Epoch 65/100
#  - 10s - loss: 0.5452 - acc: 0.8075 - val_loss: 0.5968 - val_acc: 0.7982
#
# Epoch 00065: val_loss did not improve from 0.58323
# Epoch 66/100
#  - 10s - loss: 0.5466 - acc: 0.8067 - val_loss: 0.6220 - val_acc: 0.7938
#
# Epoch 00066: val_loss did not improve from 0.58323
# Epoch 67/100
#  - 10s - loss: 0.5469 - acc: 0.8087 - val_loss: 0.5934 - val_acc: 0.8058
#
# Epoch 00067: val_loss did not improve from 0.58323
# Epoch 68/100
#  - 10s - loss: 0.5381 - acc: 0.8109 - val_loss: 0.6180 - val_acc: 0.7968
#
# Epoch 00068: val_loss did not improve from 0.58323
# Epoch 69/100
#  - 10s - loss: 0.5442 - acc: 0.8074 - val_loss: 0.5773 - val_acc: 0.8074
#
# Epoch 00069: val_loss improved from 0.58323 to 0.57728, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 70/100
#  - 10s - loss: 0.5423 - acc: 0.8080 - val_loss: 0.5871 - val_acc: 0.8056
#
# Epoch 00070: val_loss did not improve from 0.57728
# Epoch 71/100
#  - 10s - loss: 0.5317 - acc: 0.8121 - val_loss: 0.5846 - val_acc: 0.8050
#
# Epoch 00071: val_loss did not improve from 0.57728
# Epoch 72/100
#  - 10s - loss: 0.5341 - acc: 0.8095 - val_loss: 0.6001 - val_acc: 0.7960
#
# Epoch 00072: val_loss did not improve from 0.57728
# Epoch 73/100
#  - 10s - loss: 0.5330 - acc: 0.8111 - val_loss: 0.5841 - val_acc: 0.8090
#
# Epoch 00073: val_loss did not improve from 0.57728
# Epoch 74/100
#  - 10s - loss: 0.5284 - acc: 0.8144 - val_loss: 0.5922 - val_acc: 0.8032
#
# Epoch 00074: val_loss did not improve from 0.57728
# Epoch 75/100
#  - 10s - loss: 0.5202 - acc: 0.8144 - val_loss: 0.6004 - val_acc: 0.8000
#
# Epoch 00075: val_loss did not improve from 0.57728
# Epoch 76/100
#  - 10s - loss: 0.5328 - acc: 0.8111 - val_loss: 0.6029 - val_acc: 0.8046
#
# Epoch 00076: val_loss did not improve from 0.57728
# Epoch 77/100
#  - 10s - loss: 0.5185 - acc: 0.8155 - val_loss: 0.6016 - val_acc: 0.8016
#
# Epoch 00077: val_loss did not improve from 0.57728
# Epoch 78/100
#  - 10s - loss: 0.5192 - acc: 0.8156 - val_loss: 0.5732 - val_acc: 0.8120
#
# Epoch 00078: val_loss improved from 0.57728 to 0.57318, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 79/100
#  - 10s - loss: 0.5273 - acc: 0.8126 - val_loss: 0.5829 - val_acc: 0.8070
#
# Epoch 00079: val_loss did not improve from 0.57318
# Epoch 80/100
#  - 10s - loss: 0.5147 - acc: 0.8169 - val_loss: 0.5922 - val_acc: 0.8100
#
# Epoch 00080: val_loss did not improve from 0.57318
# Epoch 81/100
#  - 10s - loss: 0.5129 - acc: 0.8166 - val_loss: 0.6020 - val_acc: 0.8020
#
# Epoch 00081: val_loss did not improve from 0.57318
# Epoch 82/100
#  - 10s - loss: 0.5096 - acc: 0.8224 - val_loss: 0.5893 - val_acc: 0.8142
#
# Epoch 00082: val_loss did not improve from 0.57318
# Epoch 83/100
#  - 10s - loss: 0.5148 - acc: 0.8173 - val_loss: 0.5918 - val_acc: 0.8036
#
# Epoch 00083: val_loss did not improve from 0.57318
# Epoch 84/100
#  - 10s - loss: 0.5127 - acc: 0.8200 - val_loss: 0.5871 - val_acc: 0.8052
#
# Epoch 00084: val_loss did not improve from 0.57318
# Epoch 85/100
#  - 10s - loss: 0.5055 - acc: 0.8199 - val_loss: 0.5772 - val_acc: 0.8122
#
# Epoch 00085: val_loss did not improve from 0.57318
# Epoch 86/100
#  - 10s - loss: 0.5152 - acc: 0.8179 - val_loss: 0.5807 - val_acc: 0.8060
#
# Epoch 00086: val_loss did not improve from 0.57318
# Epoch 87/100
#  - 10s - loss: 0.5014 - acc: 0.8231 - val_loss: 0.5886 - val_acc: 0.8052
#
# Epoch 00087: val_loss did not improve from 0.57318
# Epoch 88/100
#  - 10s - loss: 0.4946 - acc: 0.8238 - val_loss: 0.5787 - val_acc: 0.8170
#
# Epoch 00088: val_loss did not improve from 0.57318
# Epoch 89/100
#  - 10s - loss: 0.5021 - acc: 0.8220 - val_loss: 0.5858 - val_acc: 0.8042
#
# Epoch 00089: val_loss did not improve from 0.57318
# Epoch 90/100
#  - 10s - loss: 0.4937 - acc: 0.8257 - val_loss: 0.6196 - val_acc: 0.7950
#
# Epoch 00090: val_loss did not improve from 0.57318
# Epoch 91/100
#  - 10s - loss: 0.4994 - acc: 0.8234 - val_loss: 0.5984 - val_acc: 0.8022
#
# Epoch 00091: val_loss did not improve from 0.57318
# Epoch 92/100
#  - 10s - loss: 0.5015 - acc: 0.8215 - val_loss: 0.5926 - val_acc: 0.8042
#
# Epoch 00092: val_loss did not improve from 0.57318
# Epoch 93/100
#  - 10s - loss: 0.4960 - acc: 0.8244 - val_loss: 0.5630 - val_acc: 0.8200
#
# Epoch 00093: val_loss improved from 0.57318 to 0.56304, saving model to C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5
# Epoch 94/100
#  - 10s - loss: 0.4946 - acc: 0.8259 - val_loss: 0.5696 - val_acc: 0.8144
#
# Epoch 00094: val_loss did not improve from 0.56304
# Epoch 95/100
#  - 10s - loss: 0.4928 - acc: 0.8251 - val_loss: 0.5834 - val_acc: 0.8092
#
# Epoch 00095: val_loss did not improve from 0.56304
# Epoch 96/100
#  - 10s - loss: 0.4874 - acc: 0.8274 - val_loss: 0.5825 - val_acc: 0.8100
#
# Epoch 00096: val_loss did not improve from 0.56304
# Epoch 97/100
#  - 10s - loss: 0.4822 - acc: 0.8279 - val_loss: 0.5880 - val_acc: 0.8068
#
# Epoch 00097: val_loss did not improve from 0.56304
# Epoch 98/100
#  - 10s - loss: 0.4844 - acc: 0.8285 - val_loss: 0.5715 - val_acc: 0.8146
#
# Epoch 00098: val_loss did not improve from 0.56304
# Epoch 99/100
#  - 10s - loss: 0.4888 - acc: 0.8255 - val_loss: 0.5705 - val_acc: 0.8148
#
# Epoch 00099: val_loss did not improve from 0.56304
# Epoch 100/100
#  - 10s - loss: 0.4820 - acc: 0.8272 - val_loss: 0.5830 - val_acc: 0.8088
#
# Epoch 00100: val_loss did not improve from 0.56304

# %% [markdown]
# ### 8. 加载分类精度最好的模型

# %%
model.load_weights(r'C:\Users\linyongxin\Desktop\ARG.weights.best.hdf5')

# %% [markdown]
# ### 9. 用测试集来测试模型的精度

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.7962

# %% [markdown]
# ### 10.可视化结果

# %%
# 获取测试集的预测结果
y_predict = model.predict(x_test)

# 定义标签
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# 可视化一些测试集样本以及他们的预测结果
fig = plt.figure(figsize=(20, 15))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=40, replace=False)):
    ax = fig.add_subplot(5, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_predict[index])
    true_index = np.argmax(y_test[index])
    ax.set_title("label:{} \n predict:{}".format(cifar10_labels[predict_index], cifar10_labels[true_index]),
                 color=("green" if predict_index == true_index else "red"))  # 如果预测正确则标绿色，否则红色
