# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we use transfer learning to train a CNN to classify dog breeds.
#
# ### 1. Load Dog Dataset
#
# Before running the code cell below, download the dataset of dog images [here](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip) and place it in the respository.
# ### 狗的数据包上文链接

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)# data里是二进制格式和字符串的组合，因为读取了整个文件夹 data是类似字典的数据类型
    dog_files = np.array(data['filenames'])#返回所有目录下照片的文件名
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)#返回0-132类别编号
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset(r'C:\Users\zhangwenqi\Desktop\data_for_neural_network\dogImages\train')#这里存的全部是文件路径和文件名
valid_files, valid_targets = load_dataset(r'C:\Users\zhangwenqi\Desktop\data_for_neural_network\dogImages\valid')
test_files, test_targets = load_dataset(r'C:\Users\zhangwenqi\Desktop\data_for_neural_network\dogImages\test')

# load ordered list of dog names
dog_names = [item[25:-1] for item in glob(r'C:\Users\zhangwenqi\Desktop\data_for_neural_network\dogImages\train\*')]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % str(len(train_files) + len(valid_files) + len(test_files)))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### 2. Visualize the First 12 Training Images

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def visualize_img(img_path, ax):
    img = cv2.imread(img_path)
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    
fig = plt.figure(figsize=(20, 10))
for i in range(12):
    ax = fig.add_subplot(3, 4, i + 1, xticks=[], yticks=[])
    visualize_img(train_files[i], ax)

# %% [markdown]
# ### 3. Obtain the VGG-16 Bottleneck Features
#
# Before running the code cell below, download the file linked [here](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG16Data.npz) and place it in the `bottleneck_features/` folder.
# 经过训练好的数据，穿过了前面的Vgg16的多层

# %%
bottleneck_features = np.load(r'C:\Users\zhangwenqi\Desktop\data_for_neural_network\dogImages\DogVGG16Data.npz')
train_vgg16 = bottleneck_features['train']
valid_vgg16 = bottleneck_features['valid']
test_vgg16 = bottleneck_features['test']

# %%
print(np.shape(train_vgg16))
print(np.shape(valid_vgg16))
print(np.shape(test_vgg16))
# Out:
# (6680, 7, 7, 512)
# (835, 7, 7, 512)
# (836, 7, 7, 512)

# %% [markdown]
# ### 4. Define a Model Architecture (Model 1)

# %%
from keras.layers import Dense, Flatten
from keras.models import Sequential

model = Sequential()
model.add(Flatten(input_shape=(7, 7, 512)))
model.add(Dense(133, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               3336837
# =================================================================
# Total params: 3,336,837
# Trainable params: 3,336,837
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 5. Define another Model Architecture (Model 2)

# %%
from keras.layers import GlobalAveragePooling2D

model = Sequential()
model.add(GlobalAveragePooling2D(input_shape=(7, 7, 512)))#增加了全局优化池GAP，用来减少参数，防止过拟合，即每7*7个方格中取一个
model.add(Dense(133, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model (Model 2)

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model (Model 2)

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='dogvgg16.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit(train_vgg16, train_targets, epochs=20, validation_data=(valid_vgg16, valid_targets), 
          callbacks=[checkpointer], verbose=1, shuffle=True)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 15.9105 - acc: 0.0120Epoch 00001: val_loss improved from inf to 15.88391, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.9064 - acc: 0.0123 - val_loss: 15.8839 - val_acc: 0.0144
# Epoch 2/20
# 6624/6680 [============================>.] - ETA: 0s - loss: 15.7670 - acc: 0.0214Epoch 00002: val_loss improved from 15.88391 to 15.67321, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.7651 - acc: 0.0216 - val_loss: 15.6732 - val_acc: 0.0275
# Epoch 3/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 15.5771 - acc: 0.0323Epoch 00003: val_loss improved from 15.67321 to 15.52824, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.5670 - acc: 0.0329 - val_loss: 15.5282 - val_acc: 0.0359
# Epoch 4/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 15.3158 - acc: 0.0485Epoch 00004: val_loss improved from 15.52824 to 15.30957, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.3163 - acc: 0.0485 - val_loss: 15.3096 - val_acc: 0.0491
# Epoch 5/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 15.2165 - acc: 0.0554Epoch 00005: val_loss improved from 15.30957 to 15.19849, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.2197 - acc: 0.0552 - val_loss: 15.1985 - val_acc: 0.0551
# Epoch 6/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 15.1615 - acc: 0.0587Epoch 00006: val_loss improved from 15.19849 to 15.14832, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.1625 - acc: 0.0587 - val_loss: 15.1483 - val_acc: 0.0599
# Epoch 7/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 15.1452 - acc: 0.0601Epoch 00007: val_loss improved from 15.14832 to 15.13364, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.1487 - acc: 0.0599 - val_loss: 15.1336 - val_acc: 0.0611
# Epoch 8/20
# 6624/6680 [============================>.] - ETA: 0s - loss: 15.1447 - acc: 0.0601Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.1456 - acc: 0.0600 - val_loss: 15.1601 - val_acc: 0.0587
# Epoch 9/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 15.1175 - acc: 0.0619Epoch 00009: val_loss improved from 15.13364 to 15.13364, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.1115 - acc: 0.0623 - val_loss: 15.1336 - val_acc: 0.0611
# Epoch 10/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 15.0902 - acc: 0.0633Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 11s 2ms/step - loss: 15.0939 - acc: 0.0630 - val_loss: 15.1878 - val_acc: 0.0575
# Epoch 11/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 14.9652 - acc: 0.0708Epoch 00011: val_loss improved from 15.13364 to 14.98281, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.9645 - acc: 0.0708 - val_loss: 14.9828 - val_acc: 0.0695
# Epoch 12/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 14.8959 - acc: 0.0750Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.8979 - acc: 0.0749 - val_loss: 14.9882 - val_acc: 0.0671
# Epoch 13/20
# 6624/6680 [============================>.] - ETA: 0s - loss: 14.8301 - acc: 0.0790Epoch 00013: val_loss improved from 14.98281 to 14.94962, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.8385 - acc: 0.0784 - val_loss: 14.9496 - val_acc: 0.0719
# Epoch 14/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 14.7938 - acc: 0.0819Epoch 00014: val_loss improved from 14.94962 to 14.94537, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.7938 - acc: 0.0819 - val_loss: 14.9454 - val_acc: 0.0707
# Epoch 15/20
# 6624/6680 [============================>.] - ETA: 0s - loss: 14.7467 - acc: 0.0838Epoch 00015: val_loss improved from 14.94537 to 14.77452, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.7509 - acc: 0.0835 - val_loss: 14.7745 - val_acc: 0.0826
# Epoch 16/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 14.6138 - acc: 0.0924Epoch 00016: val_loss improved from 14.77452 to 14.61287, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.6119 - acc: 0.0925 - val_loss: 14.6129 - val_acc: 0.0934
# Epoch 17/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 14.5681 - acc: 0.0956Epoch 00017: val_loss improved from 14.61287 to 14.58085, saving model to dogvgg16.weights.best.hdf5
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.5664 - acc: 0.0957 - val_loss: 14.5809 - val_acc: 0.0946
# Epoch 18/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 14.5092 - acc: 0.0993Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.5102 - acc: 0.0993 - val_loss: 14.6385 - val_acc: 0.0910
# Epoch 19/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 14.4820 - acc: 0.1008Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.4830 - acc: 0.1007 - val_loss: 14.6542 - val_acc: 0.0898
# Epoch 20/20
# 6656/6680 [============================>.] - ETA: 0s - loss: 14.4067 - acc: 0.1052Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 11s 2ms/step - loss: 14.4081 - acc: 0.1051 - val_loss: 14.6128 - val_acc: 0.0934

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy (Model 2)

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('dogvgg16.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set (Model 2)

# %%
model.predict(np.expand_dims(feature, axis=0))
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.6606813e-30,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00]], dtype=float32)

# %%
# get index of predicted dog breed for each image in test set
vgg16_predictions = [np.argmax(model.predict(np.expand_dims(feature, axis=0))) #argmax为取最大元素的索引值，即返回热独编码前的0-133标签编号
                     for feature in test_vgg16]
#vgg16_predictions得到每组数据对应的类别编号
# report test accuracy
test_accuracy = 100*np.sum(np.array(vgg16_predictions)==
                           np.argmax(test_targets, axis=1))/len(vgg16_predictions)
print('\nTest accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 9.2105%

# %%
vgg16_predictions
# Out:
# [38,
#  11,
#  11,
#  123,
#  105,
#  105,
#  38,
#  11,
#  87,
#  50,
#  1,
#  123,
#  88,
#  35,
#  11,
#  11,
#  50,
#  38,
#  16,
#  88,
#  50,
#  38,
#  88,
#  88,
#  35,
#  105,
#  123,
#  123,
#  105,
#  16,
#  38,
#  38,
#  11,
#  11,
#  105,
#  11,
#  105,
#  38,
#  50,
#  38,
#  38,
#  11,
#  41,
#  105,
#  105,
#  123,
#  16,
#  38,
#  87,
#  38,
#  105,
#  38,
#  105,
#  38,
#  105,
#  11,
#  11,
#  35,
#  88,
#  38,
#  11,
#  38,
#  38,
#  38,
#  16,
#  123,
#  41,
#  88,
#  38,
#  52,
#  87,
#  88,
#  16,
#  38,
#  20,
#  52,
#  88,
#  88,
#  50,
#  105,
#  11,
#  38,
#  11,
#  88,
#  38,
#  88,
#  11,
#  11,
#  123,
#  11,
#  16,
#  52,
#  35,
#  38,
#  20,
#  38,
#  88,
#  11,
#  87,
#  50,
#  38,
#  38,
#  11,
#  123,
#  88,
#  16,
#  88,
#  11,
#  11,
#  35,
#  16,
#  52,
#  88,
#  11,
#  38,
#  38,
#  16,
#  38,
#  105,
#  105,
#  11,
#  35,
#  38,
#  16,
#  38,
#  11,
#  38,
#  123,
#  38,
#  20,
#  38,
#  11,
#  1,
#  11,
#  38,
#  1,
#  38,
#  88,
#  11,
#  35,
#  11,
#  88,
#  38,
#  11,
#  11,
#  35,
#  50,
#  88,
#  123,
#  105,
#  87,
#  123,
#  38,
#  38,
#  41,
#  1,
#  105,
#  88,
#  11,
#  16,
#  88,
#  11,
#  11,
#  87,
#  105,
#  35,
#  88,
#  35,
#  38,
#  11,
#  105,
#  38,
#  38,
#  38,
#  35,
#  11,
#  38,
#  35,
#  11,
#  38,
#  105,
#  11,
#  88,
#  11,
#  50,
#  52,
#  11,
#  38,
#  123,
#  38,
#  11,
#  38,
#  88,
#  123,
#  1,
#  52,
#  87,
#  38,
#  87,
#  105,
#  11,
#  50,
#  38,
#  105,
#  88,
#  38,
#  38,
#  123,
#  35,
#  52,
#  11,
#  38,
#  1,
#  20,
#  35,
#  11,
#  16,
#  88,
#  123,
#  105,
#  38,
#  38,
#  11,
#  35,
#  11,
#  105,
#  105,
#  20,
#  1,
#  87,
#  38,
#  11,
#  38,
#  38,
#  38,
#  123,
#  35,
#  11,
#  88,
#  88,
#  11,
#  11,
#  38,
#  38,
#  38,
#  105,
#  38,
#  11,
#  35,
#  123,
#  11,
#  105,
#  11,
#  52,
#  123,
#  88,
#  88,
#  38,
#  52,
#  105,
#  38,
#  11,
#  11,
#  41,
#  11,
#  88,
#  105,
#  38,
#  38,
#  11,
#  38,
#  105,
#  16,
#  38,
#  11,
#  88,
#  123,
#  41,
#  88,
#  50,
#  11,
#  11,
#  38,
#  35,
#  35,
#  105,
#  52,
#  11,
#  105,
#  35,
#  20,
#  16,
#  38,
#  35,
#  88,
#  105,
#  123,
#  38,
#  11,
#  20,
#  38,
#  16,
#  35,
#  105,
#  11,
#  11,
#  123,
#  35,
#  11,
#  11,
#  88,
#  88,
#  35,
#  105,
#  88,
#  16,
#  1,
#  11,
#  105,
#  105,
#  11,
#  11,
#  38,
#  41,
#  35,
#  41,
#  88,
#  11,
#  11,
#  105,
#  38,
#  123,
#  88,
#  38,
#  123,
#  11,
#  105,
#  35,
#  123,
#  16,
#  105,
#  123,
#  11,
#  38,
#  11,
#  123,
#  38,
#  88,
#  38,
#  20,
#  11,
#  87,
#  88,
#  41,
#  105,
#  38,
#  88,
#  38,
#  11,
#  38,
#  123,
#  16,
#  35,
#  123,
#  11,
#  88,
#  11,
#  11,
#  38,
#  105,
#  52,
#  38,
#  11,
#  11,
#  88,
#  38,
#  11,
#  52,
#  11,
#  11,
#  11,
#  16,
#  35,
#  41,
#  38,
#  16,
#  11,
#  88,
#  20,
#  50,
#  38,
#  123,
#  11,
#  35,
#  1,
#  11,
#  38,
#  88,
#  41,
#  11,
#  11,
#  38,
#  11,
#  38,
#  87,
#  38,
#  38,
#  38,
#  88,
#  88,
#  11,
#  88,
#  11,
#  11,
#  38,
#  11,
#  50,
#  16,
#  11,
#  11,
#  16,
#  105,
#  16,
#  123,
#  105,
#  11,
#  123,
#  16,
#  38,
#  88,
#  11,
#  11,
#  105,
#  11,
#  11,
#  50,
#  35,
#  87,
#  35,
#  16,
#  35,
#  105,
#  35,
#  105,
#  11,
#  1,
#  38,
#  11,
#  88,
#  11,
#  38,
#  35,
#  38,
#  88,
#  50,
#  38,
#  105,
#  88,
#  11,
#  35,
#  11,
#  105,
#  38,
#  11,
#  11,
#  20,
#  38,
#  11,
#  88,
#  35,
#  38,
#  35,
#  105,
#  88,
#  35,
#  123,
#  38,
#  1,
#  38,
#  16,
#  38,
#  11,
#  11,
#  20,
#  35,
#  88,
#  52,
#  38,
#  16,
#  11,
#  11,
#  1,
#  88,
#  16,
#  11,
#  38,
#  35,
#  35,
#  35,
#  105,
#  35,
#  11,
#  105,
#  11,
#  20,
#  16,
#  20,
#  11,
#  38,
#  11,
#  35,
#  38,
#  38,
#  88,
#  105,
#  52,
#  35,
#  88,
#  88,
#  35,
#  123,
#  38,
#  38,
#  16,
#  105,
#  105,
#  11,
#  123,
#  38,
#  88,
#  105,
#  11,
#  11,
#  38,
#  123,
#  105,
#  38,
#  38,
#  11,
#  105,
#  1,
#  123,
#  105,
#  87,
#  20,
#  11,
#  38,
#  123,
#  11,
#  105,
#  105,
#  105,
#  20,
#  105,
#  35,
#  88,
#  38,
#  38,
#  105,
#  41,
#  41,
#  51,
#  38,
#  35,
#  105,
#  11,
#  11,
#  123,
#  38,
#  88,
#  88,
#  11,
#  50,
#  105,
#  11,
#  123,
#  123,
#  105,
#  88,
#  87,
#  123,
#  16,
#  38,
#  38,
#  50,
#  38,
#  38,
#  123,
#  11,
#  123,
#  11,
#  38,
#  88,
#  35,
#  88,
#  88,
#  35,
#  35,
#  11,
#  11,
#  105,
#  105,
#  1,
#  38,
#  105,
#  38,
#  38,
#  123,
#  11,
#  50,
#  38,
#  38,
#  87,
#  35,
#  38,
#  16,
#  105,
#  35,
#  11,
#  87,
#  11,
#  11,
#  38,
#  50,
#  87,
#  105,
#  87,
#  105,
#  105,
#  38,
#  88,
#  11,
#  11,
#  88,
#  105,
#  105,
#  11,
#  38,
#  38,
#  88,
#  11,
#  52,
#  88,
#  11,
#  11,
#  11,
#  11,
#  11,
#  88,
#  88,
#  88,
#  35,
#  105,
#  52,
#  88,
#  38,
#  105,
#  11,
#  38,
#  38,
#  38,
#  105,
#  1,
#  38,
#  11,
#  50,
#  52,
#  20,
#  38,
#  52,
#  38,
#  52,
#  35,
#  123,
#  35,
#  11,
#  11,
#  105,
#  11,
#  11,
#  87,
#  88,
#  11,
#  105,
#  35,
#  1,
#  35,
#  105,
#  105,
#  38,
#  38,
#  35,
#  41,
#  52,
#  105,
#  50,
#  41,
#  123,
#  41,
#  38,
#  123,
#  11,
#  38,
#  41,
#  1,
#  38,
#  11,
#  123,
#  123,
#  38,
#  50,
#  11,
#  38,
#  11,
#  38,
#  1,
#  11,
#  38,
#  38,
#  105,
#  16,
#  105,
#  38,
#  41,
#  11,
#  105,
#  88,
#  52,
#  11,
#  50,
#  11,
#  88,
#  1,
#  35,
#  88,
#  35,
#  87,
#  105,
#  41,
#  11,
#  38,
#  11,
#  38,
#  41,
#  38,
#  52,
#  20,
#  1,
#  105,
#  88,
#  123,
#  16,
#  50,
#  123,
#  38,
#  88,
#  11,
#  20,
#  16,
#  88,
#  105,
#  41,
#  11,
#  105,
#  11,
#  38,
#  38,
#  20,
#  35,
#  50,
#  105,
#  123,
#  38,
#  11,
#  11,
#  35,
#  38,
#  38,
#  123,
#  11,
#  88,
#  16,
#  11,
#  52,
#  11,
#  11,
#  16,
#  11,
#  11,
#  38,
#  38,
#  38,
#  88,
#  16,
#  11,
#  38,
#  16,
#  1,
#  88,
#  88,
#  16,
#  123,
#  38,
#  16,
#  38,
#  88,
#  11,
#  11,
#  38,
#  88,
#  105,
#  88,
#  105,
#  11,
#  11,
#  88,
#  38,
#  105,
#  38,
#  105,
#  88,
#  105,
#  88,
#  52,
#  11,
#  11,
#  38,
#  38,
#  1,
#  88,
#  105,
#  105,
#  105,
#  11,
#  38,
#  38]

# %% [markdown]
# ## 另一种方法

# %%
np.shape(model.predict(test_vgg16))
# Out:
# (836, 133)

# %%
model.predict(test_vgg16)
# Out:
# array([[2.6487558e-32, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)

# %%
result=model.predict(test_vgg16)
predict_vgg16=[]

for list_predict in result:
    predict_vgg16.append(np.argmax(list_predict,axis=0))

# %%
predict_vgg16
# Out:
# [38,
#  11,
#  11,
#  123,
#  105,
#  105,
#  38,
#  11,
#  87,
#  50,
#  1,
#  123,
#  88,
#  35,
#  11,
#  11,
#  50,
#  38,
#  16,
#  88,
#  50,
#  38,
#  88,
#  88,
#  35,
#  105,
#  123,
#  123,
#  105,
#  16,
#  38,
#  38,
#  11,
#  11,
#  105,
#  11,
#  105,
#  38,
#  50,
#  38,
#  38,
#  11,
#  41,
#  105,
#  105,
#  123,
#  16,
#  38,
#  87,
#  38,
#  105,
#  38,
#  105,
#  38,
#  105,
#  11,
#  11,
#  35,
#  88,
#  38,
#  11,
#  38,
#  38,
#  38,
#  16,
#  123,
#  41,
#  88,
#  38,
#  52,
#  87,
#  88,
#  16,
#  38,
#  20,
#  52,
#  88,
#  88,
#  50,
#  105,
#  11,
#  38,
#  11,
#  88,
#  38,
#  88,
#  11,
#  11,
#  123,
#  11,
#  16,
#  52,
#  35,
#  38,
#  20,
#  38,
#  88,
#  11,
#  87,
#  50,
#  38,
#  38,
#  11,
#  123,
#  88,
#  16,
#  88,
#  11,
#  11,
#  35,
#  16,
#  52,
#  88,
#  11,
#  38,
#  38,
#  16,
#  38,
#  105,
#  105,
#  11,
#  35,
#  38,
#  16,
#  38,
#  11,
#  38,
#  123,
#  38,
#  20,
#  38,
#  11,
#  1,
#  11,
#  38,
#  1,
#  38,
#  88,
#  11,
#  35,
#  11,
#  88,
#  38,
#  11,
#  11,
#  35,
#  50,
#  88,
#  123,
#  105,
#  87,
#  123,
#  38,
#  38,
#  41,
#  1,
#  105,
#  88,
#  11,
#  16,
#  88,
#  11,
#  11,
#  87,
#  105,
#  35,
#  88,
#  35,
#  38,
#  11,
#  105,
#  38,
#  38,
#  38,
#  35,
#  11,
#  38,
#  35,
#  11,
#  38,
#  105,
#  11,
#  88,
#  11,
#  50,
#  52,
#  11,
#  38,
#  123,
#  38,
#  11,
#  38,
#  88,
#  123,
#  1,
#  52,
#  87,
#  38,
#  87,
#  105,
#  11,
#  50,
#  38,
#  105,
#  88,
#  38,
#  38,
#  123,
#  35,
#  52,
#  11,
#  38,
#  1,
#  20,
#  35,
#  11,
#  16,
#  88,
#  123,
#  105,
#  38,
#  38,
#  11,
#  35,
#  11,
#  105,
#  105,
#  20,
#  1,
#  87,
#  38,
#  11,
#  38,
#  38,
#  38,
#  123,
#  35,
#  11,
#  88,
#  88,
#  11,
#  11,
#  38,
#  38,
#  38,
#  105,
#  38,
#  11,
#  35,
#  123,
#  11,
#  105,
#  11,
#  52,
#  123,
#  88,
#  88,
#  38,
#  52,
#  105,
#  38,
#  11,
#  11,
#  41,
#  11,
#  88,
#  105,
#  38,
#  38,
#  11,
#  38,
#  105,
#  16,
#  38,
#  11,
#  88,
#  123,
#  41,
#  88,
#  50,
#  11,
#  11,
#  38,
#  35,
#  35,
#  105,
#  52,
#  11,
#  105,
#  35,
#  20,
#  16,
#  38,
#  35,
#  88,
#  105,
#  123,
#  38,
#  11,
#  20,
#  38,
#  16,
#  35,
#  105,
#  11,
#  11,
#  123,
#  35,
#  11,
#  11,
#  88,
#  88,
#  35,
#  105,
#  88,
#  16,
#  1,
#  11,
#  105,
#  105,
#  11,
#  11,
#  38,
#  41,
#  35,
#  41,
#  88,
#  11,
#  11,
#  105,
#  38,
#  123,
#  88,
#  38,
#  123,
#  11,
#  105,
#  35,
#  123,
#  16,
#  105,
#  123,
#  11,
#  38,
#  11,
#  123,
#  38,
#  88,
#  38,
#  20,
#  11,
#  87,
#  88,
#  41,
#  105,
#  38,
#  88,
#  38,
#  11,
#  38,
#  123,
#  16,
#  35,
#  123,
#  11,
#  88,
#  11,
#  11,
#  38,
#  105,
#  52,
#  38,
#  11,
#  11,
#  88,
#  38,
#  11,
#  52,
#  11,
#  11,
#  11,
#  16,
#  35,
#  41,
#  38,
#  16,
#  11,
#  88,
#  20,
#  50,
#  38,
#  123,
#  11,
#  35,
#  1,
#  11,
#  38,
#  88,
#  41,
#  11,
#  11,
#  38,
#  11,
#  38,
#  87,
#  38,
#  38,
#  38,
#  88,
#  88,
#  11,
#  88,
#  11,
#  11,
#  38,
#  11,
#  50,
#  16,
#  11,
#  11,
#  16,
#  105,
#  16,
#  123,
#  105,
#  11,
#  123,
#  16,
#  38,
#  88,
#  11,
#  11,
#  105,
#  11,
#  11,
#  50,
#  35,
#  87,
#  35,
#  16,
#  35,
#  105,
#  35,
#  105,
#  11,
#  1,
#  38,
#  11,
#  88,
#  11,
#  38,
#  35,
#  38,
#  88,
#  50,
#  38,
#  105,
#  88,
#  11,
#  35,
#  11,
#  105,
#  38,
#  11,
#  11,
#  20,
#  38,
#  11,
#  88,
#  35,
#  38,
#  35,
#  105,
#  88,
#  35,
#  123,
#  38,
#  1,
#  38,
#  16,
#  38,
#  11,
#  11,
#  20,
#  35,
#  88,
#  52,
#  38,
#  16,
#  11,
#  11,
#  1,
#  88,
#  16,
#  11,
#  38,
#  35,
#  35,
#  35,
#  105,
#  35,
#  11,
#  105,
#  11,
#  20,
#  16,
#  20,
#  11,
#  38,
#  11,
#  35,
#  38,
#  38,
#  88,
#  105,
#  52,
#  35,
#  88,
#  88,
#  35,
#  123,
#  38,
#  38,
#  16,
#  105,
#  105,
#  11,
#  123,
#  38,
#  88,
#  105,
#  11,
#  11,
#  38,
#  123,
#  105,
#  38,
#  38,
#  11,
#  105,
#  1,
#  123,
#  105,
#  87,
#  20,
#  11,
#  38,
#  123,
#  11,
#  105,
#  105,
#  105,
#  20,
#  105,
#  35,
#  88,
#  38,
#  38,
#  105,
#  41,
#  41,
#  51,
#  38,
#  35,
#  105,
#  11,
#  11,
#  123,
#  38,
#  88,
#  88,
#  11,
#  50,
#  105,
#  11,
#  123,
#  123,
#  105,
#  88,
#  87,
#  123,
#  16,
#  38,
#  38,
#  50,
#  38,
#  38,
#  123,
#  11,
#  123,
#  11,
#  38,
#  88,
#  35,
#  88,
#  88,
#  35,
#  35,
#  11,
#  11,
#  105,
#  105,
#  1,
#  38,
#  105,
#  38,
#  38,
#  123,
#  11,
#  50,
#  38,
#  38,
#  87,
#  35,
#  38,
#  16,
#  105,
#  35,
#  11,
#  87,
#  11,
#  11,
#  38,
#  50,
#  87,
#  105,
#  87,
#  105,
#  105,
#  38,
#  88,
#  11,
#  11,
#  88,
#  105,
#  105,
#  11,
#  38,
#  38,
#  88,
#  11,
#  52,
#  88,
#  11,
#  11,
#  11,
#  11,
#  11,
#  88,
#  88,
#  88,
#  35,
#  105,
#  52,
#  88,
#  38,
#  105,
#  11,
#  38,
#  38,
#  38,
#  105,
#  1,
#  38,
#  11,
#  50,
#  52,
#  20,
#  38,
#  52,
#  38,
#  52,
#  35,
#  123,
#  35,
#  11,
#  11,
#  105,
#  11,
#  11,
#  87,
#  88,
#  11,
#  105,
#  35,
#  1,
#  35,
#  105,
#  105,
#  38,
#  38,
#  35,
#  41,
#  52,
#  105,
#  50,
#  41,
#  123,
#  41,
#  38,
#  123,
#  11,
#  38,
#  41,
#  1,
#  38,
#  11,
#  123,
#  123,
#  38,
#  50,
#  11,
#  38,
#  11,
#  38,
#  1,
#  11,
#  38,
#  38,
#  105,
#  16,
#  105,
#  38,
#  41,
#  11,
#  105,
#  88,
#  52,
#  11,
#  50,
#  11,
#  88,
#  1,
#  35,
#  88,
#  35,
#  87,
#  105,
#  41,
#  11,
#  38,
#  11,
#  38,
#  41,
#  38,
#  52,
#  20,
#  1,
#  105,
#  88,
#  123,
#  16,
#  50,
#  123,
#  38,
#  88,
#  11,
#  20,
#  16,
#  88,
#  105,
#  41,
#  11,
#  105,
#  11,
#  38,
#  38,
#  20,
#  35,
#  50,
#  105,
#  123,
#  38,
#  11,
#  11,
#  35,
#  38,
#  38,
#  123,
#  11,
#  88,
#  16,
#  11,
#  52,
#  11,
#  11,
#  16,
#  11,
#  11,
#  38,
#  38,
#  38,
#  88,
#  16,
#  11,
#  38,
#  16,
#  1,
#  88,
#  88,
#  16,
#  123,
#  38,
#  16,
#  38,
#  88,
#  11,
#  11,
#  38,
#  88,
#  105,
#  88,
#  105,
#  11,
#  11,
#  88,
#  38,
#  105,
#  38,
#  105,
#  88,
#  105,
#  88,
#  52,
#  11,
#  11,
#  38,
#  38,
#  1,
#  88,
#  105,
#  105,
#  105,
#  11,
#  38,
#  38]
